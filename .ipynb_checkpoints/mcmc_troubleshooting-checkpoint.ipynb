# %%
# We're going to generate a synthetic dataset from a given model, and then fit to the data.
# as per section 3.1 of Gubler & Oka

# import necessary packages
import numpy as np
import emcee
import matplotlib.pyplot as pl
import scipy.optimize as op
import scipy.integrate as integrate
import corner

# Choose the "true" parameters.
# equation (3.2)

mrho = 0.77 # GeV; mass of rho meson
mpi = 0.14 # GeV; mass of pion
om0 = 1.3 # GeV; 
d = 0.2 # GeV; delta
g = 5.45 # g_{\rho \pi \pi} coupling
alpha = 0.5 # strong coupling constant
fP = mrho / g

# Generate some synthetic data from the model.
N = 100
# omeg = np.sort(10*np.random.rand(N))
# yerr = 0.1+0.5*np.random.rand(N)


def Gamma_rho(om):
    return (g**2 * mrho/ (48 * np.pi))*(1 - 4*mpi**2 / om**2)**(3.0/2.0)*np.heaviside(om, 2*mpi) # Model Spectral Function, equation (3.1)
def rho_in(om, switch = 1):
    return (2*fP**2/np.pi)*(Gamma_rho(om)*mrho/((om**2-mrho**2)**2 + Gamma_rho(om)**2*mrho**2))*np.heaviside(switch, 1) + (1/(4*np.pi**2))*(1 + alpha / np.pi) * (1 / (1 + np.exp((om0-om)/d))) # Model Spectral Function, equation (3.1)
def mom(om):
    return (1/(4*np.pi**2))*(1 + alpha / np.pi) * (1 / (1 + np.exp((om0-om)/d))) # Default model, equation 3.3


# integrate spectral function to find G_{mock}
def integrand(om, M, switch = 1):
    # f = lambda om, M:(2.0/M**2)*np.exp(-om**2/M)*om*rho_in
    f = (2.0/M**2)*np.exp(-om**2/M)*om*rho_in(om, switch)
    return f

# G_OPE = lambda M: integrate.quad((2/M**2)*np.exp(-om**2/M)*om*rho_in(om), 0, np.inf)[0]
# G_OPE = integrate.quad((2/M**2)*np.exp(-om**2/M)*om*rho_in, 0, np.inf)[0]

def G_OPE(w, M, switch = 1):
    f = lambda w, M: (2/M)*np.exp(-w**2/M)*w*rho_in(w, switch)
    return integrate.quad(f, 0, np.inf, args=(M))[0]

# visualize synthetic data
# plot model
om_dom = np.linspace(0,10,100)

fig, axes = pl.subplots()
axes.plot(om_dom, rho_in(om_dom), 'r')
#axes.plot(om_dom, mom(om_dom), 'r--')
axes.set_xlabel(r'$\omega$')
axes.set_ylabel(r'$\rho_{in}(\omega)$')
axes.set_title('Model')
pl.show()                                                                                                                                

M_dom = np.linspace(0, 3, 3000)

iterable = (G_OPE(0., M) for M in M_dom)
data = np.fromiter(iterable, np.float)

iterable_cont = (G_OPE(0., M, -1) for M in M_dom)
data_cont = np.fromiter(iterable_cont, np.float)


fig, axes = pl.subplots()
axes.plot(M_dom, data, 'r')
axes.plot(M_dom, data_cont, 'r--')
axes.set_xlabel(r'$M$')
axes.set_ylabel(r'$G_{mock}(M)$')
axes.set_title(r'$G_{mock}$')
pl.show()

# https://stackoverflow.com/questions/40960968/python-plotting-an-integral

# def H(z, omega_m, H_0=70):
#     omega_lambda = 1 - omega_m
#     z_prime = ((1 + z) ** 3)
#     wurzel = np.sqrt(omega_m * z_prime + omega_lambda)

#     return H_0 * wurzel


# def H_inv(z, omega_m, H_0=70):
#    return 1 / (H(z, omega_m, H_0=70))

# I need an array of G_OPE(M) for given values of M between 0 and 3.

# M0 = 0
# Mf = 1
# Ms = np.linspace(M0, Mf, 100)

# fig, ax = pl.subplots(nrows=1,ncols=1, figsize=(16,9))

# for omega_m in np.linspace(0, 1, 10):
#     d_Ls = np.linspace(M0, Mf, 100)
#     for index in range(Ms.size):
#         d_Ls[index] = G_OPE(Ms[index])
#     ax.plot(Ms,d_Ls, label='$\Omega$ = {:.2f}'.format(omega_m))
# ax.legend(loc='best')
# pl.show()
# Out:
# /home/jho/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:30: RuntimeWarning: divide by zero encountered in true_divide
# /home/jho/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:30: RuntimeWarning: invalid value encountered in power
# /home/jho/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:32: RuntimeWarning: invalid value encountered in true_divide
# /home/jho/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:47: RuntimeWarning: divide by zero encountered in double_scalars
# /home/jho/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:47: RuntimeWarning: invalid value encountered in double_scalars
# /home/jho/anaconda3/lib/python3.5/site-packages/scipy/integrate/quadpack.py:390: ComplexWarning: Casting complex values to real discards the imaginary part
#   return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
# /home/jho/anaconda3/lib/python3.5/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   warnings.warn(msg, IntegrationWarning)

# %%
M_dom
# Out:
# array([ 1.        ,  1.02020202,  1.04040404,  1.06060606,  1.08080808,
#         1.1010101 ,  1.12121212,  1.14141414,  1.16161616,  1.18181818,
#         1.2020202 ,  1.22222222,  1.24242424,  1.26262626,  1.28282828,
#         1.3030303 ,  1.32323232,  1.34343434,  1.36363636,  1.38383838,
#         1.4040404 ,  1.42424242,  1.44444444,  1.46464646,  1.48484848,
#         1.50505051,  1.52525253,  1.54545455,  1.56565657,  1.58585859,
#         1.60606061,  1.62626263,  1.64646465,  1.66666667,  1.68686869,
#         1.70707071,  1.72727273,  1.74747475,  1.76767677,  1.78787879,
#         1.80808081,  1.82828283,  1.84848485,  1.86868687,  1.88888889,
#         1.90909091,  1.92929293,  1.94949495,  1.96969697,  1.98989899,
#         2.01010101,  2.03030303,  2.05050505,  2.07070707,  2.09090909,
#         2.11111111,  2.13131313,  2.15151515,  2.17171717,  2.19191919,
#         2.21212121,  2.23232323,  2.25252525,  2.27272727,  2.29292929,
#         2.31313131,  2.33333333,  2.35353535,  2.37373737,  2.39393939,
#         2.41414141,  2.43434343,  2.45454545,  2.47474747,  2.49494949,
#         2.51515152,  2.53535354,  2.55555556,  2.57575758,  2.5959596 ,
#         2.61616162,  2.63636364,  2.65656566,  2.67676768,  2.6969697 ,
#         2.71717172,  2.73737374,  2.75757576,  2.77777778,  2.7979798 ,
#         2.81818182,  2.83838384,  2.85858586,  2.87878788,  2.8989899 ,
#         2.91919192,  2.93939394,  2.95959596,  2.97979798,  3.        ])

# %%
G_OPE(1, 1)
# Out:
# /home/jho/anaconda3/lib/python3.5/site-packages/scipy/integrate/quadpack.py:390: ComplexWarning: Casting complex values to real discards the imaginary part
#   return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
# 0.026322187428750716

# %%
G_OPE(1, 1, -1)
# Out:
# /home/jho/anaconda3/lib/python3.5/site-packages/scipy/integrate/quadpack.py:390: ComplexWarning: Casting complex values to real discards the imaginary part
#   return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
# 0.0067793367773549785

# %%
# THIS SEEMS TO BE A PROMISING AVENUE

# %%
G_OPE(0, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-81175c234364> in <module>()
# ----> 1 G_OPE(0, 1)
#
# <ipython-input-5-155a354489a6> in G_OPE(w, M)
#       3 def G_OPE(w, M):
#       4     f = lambda w, M: (2/M)*np.exp(-w**2/M)*w*rho_in(w)
# ----> 5     return integrate.quad(f, 0, np.inf, args=(M))[0]
#
# /home/jho/anaconda3/lib/python3.5/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     321     if (weight is None):
#     322         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 323                        points)
#     324     else:
#     325         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /home/jho/anaconda3/lib/python3.5/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     388             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     389         else:
# --> 390             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#     391     else:
#     392         if infbounds != 0:
#
# <ipython-input-5-155a354489a6> in <lambda>(w, M)
#       2
#       3 def G_OPE(w, M):
# ----> 4     f = lambda w, M: (2/M)*np.exp(-w**2/M)*w*rho_in(w)
#       5     return integrate.quad(f, 0, np.inf, args=(M))[0]
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
iterable = (G_OPE(0., M) for M in np.linspace(0, 3, 300))
data = np.fromiter(iterable, np.float)
fig, axes = pl.subplots()
axes.plot(data, 'r')
axes.plot(om, mom, 'r--')
axes.set_xlabel(r'$M$')
axes.set_ylabel(r'$G_{mock}(M)$')
axes.set_title(r'$G_{mock}$')
pl.show()

# %%
om

# %%
np.linspace(0, 3, 300)

# %%
pl.plot(map(lambda x:x**2, range(1,10)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c9b811c9582f> in <module>()
# ----> 1 pl.plot(map(lambda x:x**2, range(1,10)))
#
# /home/jho/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3159         ax.hold(hold)
#    3160     try:
# -> 3161         ret = ax.plot(*args, **kwargs)
#    3162     finally:
#    3163         ax.hold(washold)
#
# /home/jho/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /home/jho/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1381
#    1382         for line in self._get_lines(*args, **kwargs):
# -> 1383             self.add_line(line)
#    1384             lines.append(line)
#    1385
#
# /home/jho/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1701             line.set_clip_path(self.patch)
#    1702
# -> 1703         self._update_line_limits(line)
#    1704         if not line.get_label():
#    1705             line.set_label('_line%d' % len(self.lines))
#
# /home/jho/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1723         Figures out the data limit of the given line, updating self.dataLim.
#    1724         """
# -> 1725         path = line.get_path()
#    1726         if path.vertices.size == 0:
#    1727             return
#
# /home/jho/anaconda3/lib/python3.5/site-packages/matplotlib/lines.py in get_path(self)
#     936         """
#     937         if self._invalidy or self._invalidx:
# --> 938             self.recache()
#     939         return self._path
#     940
#
# /home/jho/anaconda3/lib/python3.5/site-packages/matplotlib/lines.py in recache(self, always)
#     632                 y = ma.asarray(yconv, np.float_).filled(np.nan)
#     633             else:
# --> 634                 y = np.asarray(yconv, np.float_)
#     635             y = y.ravel()
#     636         else:
#
# /home/jho/anaconda3/lib/python3.5/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# TypeError: float() argument must be a string or a number, not 'map'
